# %%
import wandb
api = wandb.Api()
run = api.run("/vlm_rl/rl_eval/runs/sffpturm")
# Out:
# wandb: Currently logged in as: axi42 (vlm_rl) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
tbl = run.history(keys=["success","fpg_trigger_count"])

# %%
success_rate
# Out:
#      _step  success
# 0        0        1
# 1        1        1
# 2        7        1
# 3        8        1
# 4        9        1
# ..     ...      ...
# 495   2610        1
# 496   2619        1
# 497   2624        1
# 498   2630        0
# 499   2636        0
#
# [500 rows x 2 columns]
